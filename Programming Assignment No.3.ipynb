# %% [markdown]
# 1.	Write a Python Program to Check if a Number is Positive, Negative or Zero?
# 2.	Write a Python Program to Check if a Number is Odd or Even?
# 3.	Write a Python Program to Check Leap Year?
# 4.	Write a Python Program to Check Prime Number?
# 5.	Write a Python Program to Print all Prime Numbers in an Interval of 1-10000?

# %%
n = float(input("Enter the number"))
if n<0:
    print("number is negative")
elif n>0:
    print("number is positive")
elif n==0:
    print("number is zero")
# Out:
# Enter the number1
# number is positive

# %%
n = float(input("Enter a number"))
if n%2==0:
    print("number is even")
else:
    print("number is odd")
# Out:
# Enter a number2
# number is even

# %%
year =int(input("enter a year"))
if year%4==0:
    print("This is a leap year")
else:
    print("Not a leap year")
# Out:
# enter a year2024
# This is a leap year

# %%
num = int(input("Enter a number: "))

# If number is greater than 1
if num > 1:
   # Check if factor exist  
   for i in range(2,num):
       if (num % i) == 0:
           print(num,"is not a prime number")
           break
   else:
       print(num,"is a prime number")
else:
    print('enter valid number')
# Out:
# Enter a number: -1
# valid number

# %%
import pandas as pd

# %%
dframe = pd.read_csv("NIFTY.csv")
dframe
# Out:
#       TICKER        DATE   TIME     OPEN     HIGH      LOW    CLOSE
# 0      NIFTY  01-01-2021  09:16  13997.9  14020.8  13991.3  14013.2
# 1      NIFTY  01-01-2021  09:17  14014.8  14018.5  14008.2  14009.0
# 2      NIFTY  01-01-2021  09:18  14008.0  14013.1  14005.0  14012.7
# 3      NIFTY  01-01-2021  09:19  14013.7  14019.1  14013.7  14016.2
# 4      NIFTY  01-01-2021  09:20  14015.5  14017.8  14012.0  14015.5
# ...      ...         ...    ...      ...      ...      ...      ...
# 92253  NIFTY  31-12-2021  15:26  17357.9  17358.5  17353.8  17356.3
# 92254  NIFTY  31-12-2021  15:27  17356.1  17359.7  17355.6  17359.3
# 92255  NIFTY  31-12-2021  15:28  17358.8  17360.5  17356.2  17359.8
# 92256  NIFTY  31-12-2021  15:29  17359.8  17360.9  17351.1  17353.6
# 92257  NIFTY  31-12-2021  15:30  17353.4  17365.4  17353.1  17364.3
#
# [92258 rows x 7 columns]

# %%
dframe.describe()
# Out:
#                OPEN          HIGH           LOW         CLOSE
# count  92258.000000  92258.000000  92258.000000  92258.000000
# mean   16027.133744  16030.706030  16023.521701  16027.097056
# std     1282.500687   1282.446009   1282.559915   1282.484822
# min    13604.800000  13614.400000  13596.800000  13602.800000
# 25%    14849.000000  14852.700000  14845.300000  14849.000000
# 50%    15787.600000  15790.000000  15785.200000  15787.600000
# 75%    17288.800000  17292.500000  17284.875000  17288.775000
# max    18604.400000  18604.400000  18588.700000  18592.200000

# %%
dframe.head(10)
# Out:
#   TICKER        DATE   TIME     OPEN     HIGH      LOW    CLOSE
# 0  NIFTY  01-01-2021  09:16  13997.9  14020.8  13991.3  14013.2
# 1  NIFTY  01-01-2021  09:17  14014.8  14018.5  14008.2  14009.0
# 2  NIFTY  01-01-2021  09:18  14008.0  14013.1  14005.0  14012.7
# 3  NIFTY  01-01-2021  09:19  14013.7  14019.1  14013.7  14016.2
# 4  NIFTY  01-01-2021  09:20  14015.5  14017.8  14012.0  14015.5
# 5  NIFTY  01-01-2021  09:21  14016.0  14021.8  14006.4  14020.8
# 6  NIFTY  01-01-2021  09:22  14020.7  14023.5  14018.7  14019.5
# 7  NIFTY  01-01-2021  09:23  14018.4  14021.0  14017.5  14019.5
# 8  NIFTY  01-01-2021  09:24  14020.0  14020.0  14007.6  14010.5
# 9  NIFTY  01-01-2021  09:25  14010.3  14014.1  14007.3  14014.1

# %%
names = pd.read_csv("Book1.csv")
surnames = pd.read_csv("Book2.csv")

# %%
m = pd.concat(map(pd.read_csv,["Book1.csv","Book2.csv"]),)
m
# Out:
#           1      2     3
# 0    gaurav      h   NaN
# 1    ganesh  fghdf   NaN
# 2     vijay   fhfd   NaN
# 0     patil    NaN  sdfs
# 1  nalavade    NaN   dfs
# 2    lawate    NaN   sfs

# %%
surnames
# Out:
#       patil
# 0  nalavade
# 1    lawate

# %%
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 merges = pd.merge(names["gaurav"], surnames["patil"])
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:682, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     678     # stacklevel chosen to be correct when this is reached via pd.merge
#     679     # (and not DataFrame.join)
#     680     warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
# --> 682 self._validate_specification()
#     684 cross_col = None
#     685 if self.how == "cross":
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1349, in _MergeOperation._validate_specification(self)
#    1347 common_cols = left_cols.intersection(right_cols)
#    1348 if len(common_cols) == 0:
# -> 1349     raise MergeError(
#    1350         "No common columns to perform merge on. "
#    1351         f"Merge options: left_on={self.left_on}, "
#    1352         f"right_on={self.right_on}, "
#    1353         f"left_index={self.left_index}, "
#    1354         f"right_index={self.right_index}"
#    1355     )
#    1356 if (
#    1357     not left_cols.join(common_cols, how="inner").is_unique
#    1358     or not right_cols.join(common_cols, how="inner").is_unique
#    1359 ):
#    1360     raise MergeError(f"Data columns not unique: {repr(common_cols)}")
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False
